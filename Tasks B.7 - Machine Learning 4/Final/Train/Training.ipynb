# %%
# !nvidia-smi
# Out:
# Sun Oct 29 05:01:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# **Install Dependencies**

# %%
# !pip install -q numpy
# !pip install -q matplotlib
# !pip install -q pandas
# !pip install -q tensorflow
# !pip install -q scikit-learn
# !pip install -q pandas-datareader
# !pip install -q yfinance
# !pip install --upgrade mplfinance
# !pip install -q pmdarima
# !pip install -q transformers
# !pip install -q transformers[torch]
# !pip install -q numpy
# !pip install -q torch
# !pip install -q scikit-learn
# !pip3 install -q datasets
# Code Source Note: https://github.com/twopirllc/pandas-ta
# !pip install -q pandas_ta
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 59.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pandas_ta (setup.py) ... done

# %% [markdown]
# **Setting up Drive**

# %%
import os
import sys
from google.colab import drive
drive.mount('/content/drive')

# Set the working directory for the tasks
SKELETON_DIR = '/content/drive/MyDrive/stock-prediction/Final/Training'
os.chdir(SKELETON_DIR)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Dependencies**

# %%
from models import intialized_lstm, intialize_bert_model
from dataset import create_datasets, create_finbert_datasets, finbert_dataset_splitting, finbert_datasets_mapping, finbert_dataset_format
from train import train_lstm, lstm_predict_test, trainer_finbert
from transformers import pipeline

# %% [markdown]
# **Setting Up Datasets and Intialized Model for Training Purpose**

# %% [markdown]
# ## LSTM

# %%
# Datasets for Training LSTM/GRU Model
''' data = raw data
    df = cleaned data
    train_data + test_data = splitted data
    train_feature_scaler + train_target_scaler = scaler
    '''
start='2019-01-01'
end='2023-09-07'
ticker='TSLA'
data, df, train_data, test_data, train_feature_scaler, train_target_scaler, x_train, x_test, y_train, y_test = create_datasets(start, end, ticker)
# Out:
# Loading Existing Data
# Loading Prepared Data
# Loading Existing Train and Test Data
# Train Data Shape: (942, 14)
# Test Data Shape: (236, 14)

# %%
# Intiailized LSTM Model
input_shape = (x_train.shape[1], x_train.shape[2])

# Intiailize layer configs
layer_configs = [
    { 'type': 'GRU', 'units': 100, 'return_sequences': True, 'dropout': 0.2 },
    { 'type': 'GRU', 'units': 100, 'return_sequences': False, 'dropout': 0.2 }
]

lstm_model = intialized_lstm(input_shape, layer_configs)
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30, 100)           33600
#
#  dropout (Dropout)           (None, 30, 100)           0
#
#  gru_1 (GRU)                 (None, 100)               60600
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 94301 (368.36 KB)
# Trainable params: 94301 (368.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30, 100)           33600
#
#  dropout (Dropout)           (None, 30, 100)           0
#
#  gru_1 (GRU)                 (None, 100)               60600
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 94301 (368.36 KB)
# Trainable params: 94301 (368.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Finbert

# %%
# Initialized Bert Model
finbert_model, finbert_tokenizer = intialize_bert_model(path='bert-base-uncased', num_labels=3)
print(finbert_model.config)
print(finbert_tokenizer)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "negative",
#     "1": "positive",
#     "2": "neutral"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "negative": 0,
#     "neutral": 2,
#     "positive": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.34.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# BertTokenizer(name_or_path='bert-base-uncased', vocab_size=30522, model_max_length=512, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
# Datasets for Training Finbert Model
train_path = 'datasets/train-00000-of-00001-db1b9d43fb2c6ce5.parquet'
test_path = 'datasets/test-00000-of-00001-106b8ac96d1287d8.parquet'

train_finbert_dataset = create_finbert_datasets(train_path)
test_finbert_dataset = create_finbert_datasets(test_path)

# Split train dataset for validation
train_finbert_dataset, val_finbert_dataset = finbert_dataset_splitting(train_finbert_dataset)

# Mapping
train_finbert_dataset = finbert_datasets_mapping(train_finbert_dataset, finbert_tokenizer)
val_finbert_dataset = finbert_datasets_mapping(val_finbert_dataset, finbert_tokenizer)
test_finbert_dataset = finbert_datasets_mapping(test_finbert_dataset, finbert_tokenizer)

# Correct Format
train_finbert_dataset = finbert_dataset_format(train_finbert_dataset, debug=True)
val_finbert_dataset = finbert_dataset_format(val_finbert_dataset, debug=True)
test_finbert_dataset = finbert_dataset_format(test_finbert_dataset, debug=True)
# Out:
# Map:   0%|          | 0/8588 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 8588
# })
# Map:   0%|          | 0/955 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 955
# })
# Map:   0%|          | 0/2388 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 2388
# })
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 8588
# })
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 955
# })
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 2388
# })

# %% [markdown]
# **Training**

# %% [markdown]
# ## LSTM

# %%
history = train_lstm(lstm_model, x_train=x_train, y_train=y_train, batch_size=1, epochs=100)
# Out:
# Learning rate:  0.001
# Epoch 1/100
# 722/729 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.0028
# Epoch 1: val_loss improved from inf to 0.00694, saving model to model/best_model.pt
#
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to model/best_model_acc.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 729/729 [==============================] - 22s 17ms/step - loss: 0.0080 - accuracy: 0.0027 - val_loss: 0.0069 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 729/729 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.0027
# Epoch 2: val_loss improved from 0.00694 to 0.00215, saving model to model/best_model.pt
#
# Epoch 2: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 12s 16ms/step - loss: 0.0038 - accuracy: 0.0027 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/100
# 727/729 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.0028
# Epoch 3: val_loss did not improve from 0.00215
#
# Epoch 3: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0033 - accuracy: 0.0027 - val_loss: 0.0064 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/100
# 729/729 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.0027
# Epoch 4: val_loss did not improve from 0.00215
#
# Epoch 4: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 8ms/step - loss: 0.0044 - accuracy: 0.0027 - val_loss: 0.0023 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/100
# 726/729 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.0028
# Epoch 5: val_loss improved from 0.00215 to 0.00176, saving model to model/best_model.pt
#
# Epoch 5: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 11s 15ms/step - loss: 0.0034 - accuracy: 0.0027 - val_loss: 0.0018 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/100
# 724/729 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.0028
# Epoch 6: val_loss did not improve from 0.00176
#
# Epoch 6: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 7s 10ms/step - loss: 0.0027 - accuracy: 0.0027 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/100
# 728/729 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.0027
# Epoch 7: val_loss did not improve from 0.00176
#
# Epoch 7: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0032 - accuracy: 0.0027 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/100
# 727/729 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.0028
# Epoch 8: val_loss did not improve from 0.00176
#
# Epoch 8: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0025 - accuracy: 0.0027 - val_loss: 0.0033 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/100
# 728/729 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.0027
# Epoch 9: val_loss improved from 0.00176 to 0.00172, saving model to model/best_model.pt
#
# Epoch 9: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 11s 15ms/step - loss: 0.0025 - accuracy: 0.0027 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/100
# 723/729 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.0028
# Epoch 10: val_loss did not improve from 0.00172
#
# Epoch 10: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0030 - accuracy: 0.0027 - val_loss: 0.0410 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/100
# 726/729 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.0028
# Epoch 11: val_loss improved from 0.00172 to 0.00169, saving model to model/best_model.pt
#
# Epoch 11: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 12s 16ms/step - loss: 0.0019 - accuracy: 0.0027 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/100
# 729/729 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.0027
# Epoch 12: val_loss did not improve from 0.00169
#
# Epoch 12: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 7s 10ms/step - loss: 0.0023 - accuracy: 0.0027 - val_loss: 0.0035 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/100
# 723/729 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.0028
# Epoch 13: val_loss did not improve from 0.00169
#
# Epoch 13: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0020 - accuracy: 0.0027 - val_loss: 0.0028 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/100
# 725/729 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.0028
# Epoch 14: val_loss improved from 0.00169 to 0.00159, saving model to model/best_model.pt
#
# Epoch 14: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 12s 16ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/100
# 724/729 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.0028
# Epoch 15: val_loss did not improve from 0.00159
#
# Epoch 15: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0022 - accuracy: 0.0027 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/100
# 721/729 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.0028
# Epoch 16: val_loss improved from 0.00159 to 0.00158, saving model to model/best_model.pt
#
# Epoch 16: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 12s 16ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/100
# 727/729 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.0028
# Epoch 17: val_loss did not improve from 0.00158
#
# Epoch 17: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0019 - accuracy: 0.0027 - val_loss: 0.0041 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/100
# 727/729 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.0028
# Epoch 18: val_loss did not improve from 0.00158
#
# Epoch 18: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 8ms/step - loss: 0.0019 - accuracy: 0.0027 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/100
# 725/729 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.0028
# Epoch 19: val_loss did not improve from 0.00158
#
# Epoch 19: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 8ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0041 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/100
# 723/729 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.0028
# Epoch 20: val_loss did not improve from 0.00158
#
# Epoch 20: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0017 - accuracy: 0.0027 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/100
# 725/729 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.0028
# Epoch 21: val_loss did not improve from 0.00158
#
# Epoch 21: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 8ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0031 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/100
# 723/729 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.0028
# Epoch 22: val_loss did not improve from 0.00158
#
# Epoch 22: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 8ms/step - loss: 0.0019 - accuracy: 0.0027 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/100
# 726/729 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.0028
# Epoch 23: val_loss did not improve from 0.00158
#
# Epoch 23: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0033 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/100
# 725/729 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.0028
# Epoch 24: val_loss did not improve from 0.00158
#
# Epoch 24: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 9ms/step - loss: 0.0019 - accuracy: 0.0027 - val_loss: 0.0072 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/100
# 725/729 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.0028
# Epoch 25: val_loss did not improve from 0.00158
#
# Epoch 25: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0020 - accuracy: 0.0027 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/100
# 724/729 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.0028
# Epoch 26: val_loss did not improve from 0.00158
#
# Epoch 26: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0017 - accuracy: 0.0027 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/100
# 729/729 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.0027
# Epoch 27: val_loss did not improve from 0.00158
#
# Epoch 27: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 7s 10ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0030 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/100
# 729/729 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.0027
# Epoch 28: val_loss improved from 0.00158 to 0.00157, saving model to model/best_model.pt
#
# Epoch 28: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 11s 16ms/step - loss: 0.0013 - accuracy: 0.0027 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/100
# 726/729 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.0028
# Epoch 29: val_loss did not improve from 0.00157
#
# Epoch 29: val_accuracy did not improve from 0.00000
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 729/729 [==============================] - 6s 9ms/step - loss: 0.0019 - accuracy: 0.0027 - val_loss: 0.0034 - val_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Learning rate:  0.001
# Epoch 30/100
# 729/729 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.0027
# Epoch 30: val_loss did not improve from 0.00157
#
# Epoch 30: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0015 - accuracy: 0.0027 - val_loss: 0.0030 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 31/100
# 728/729 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.0027
# Epoch 31: val_loss did not improve from 0.00157
#
# Epoch 31: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 9ms/step - loss: 0.0015 - accuracy: 0.0027 - val_loss: 0.0038 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 32/100
# 726/729 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.0028
# Epoch 32: val_loss did not improve from 0.00157
#
# Epoch 32: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0059 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 33/100
# 728/729 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.0027
# Epoch 33: val_loss did not improve from 0.00157
#
# Epoch 33: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0023 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 34/100
# 725/729 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.0028
# Epoch 34: val_loss did not improve from 0.00157
#
# Epoch 34: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 7s 9ms/step - loss: 0.0016 - accuracy: 0.0027 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 35/100
# 721/729 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.0028
# Epoch 35: val_loss did not improve from 0.00157
#
# Epoch 35: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0016 - accuracy: 0.0027 - val_loss: 0.0041 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 36/100
# 725/729 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.0028
# Epoch 36: val_loss did not improve from 0.00157
#
# Epoch 36: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0016 - accuracy: 0.0027 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 37/100
# 724/729 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.0028
# Epoch 37: val_loss did not improve from 0.00157
#
# Epoch 37: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 7s 9ms/step - loss: 0.0017 - accuracy: 0.0027 - val_loss: 0.0025 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 38/100
# 723/729 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.0028
# Epoch 38: val_loss did not improve from 0.00157
#
# Epoch 38: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0018 - accuracy: 0.0027 - val_loss: 0.0024 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 39/100
# 724/729 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.0028
# Epoch 39: val_loss did not improve from 0.00157
#
# Epoch 39: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0014 - accuracy: 0.0027 - val_loss: 0.0027 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 40/100
# 722/729 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.0028
# Epoch 40: val_loss did not improve from 0.00157
#
# Epoch 40: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 9ms/step - loss: 0.0017 - accuracy: 0.0027 - val_loss: 0.0025 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 41/100
# 721/729 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.0028
# Epoch 41: val_loss did not improve from 0.00157
#
# Epoch 41: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0017 - accuracy: 0.0027 - val_loss: 0.0048 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 42/100
# 727/729 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.0028
# Epoch 42: val_loss did not improve from 0.00157
#
# Epoch 42: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 5s 7ms/step - loss: 0.0015 - accuracy: 0.0027 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Learning rate:  0.001
# Epoch 43/100
# 728/729 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.0027
# Epoch 43: val_loss did not improve from 0.00157
#
# Epoch 43: val_accuracy did not improve from 0.00000
# 729/729 [==============================] - 6s 9ms/step - loss: 0.0016 - accuracy: 0.0027 - val_loss: 0.0021 - val_accuracy: 0.0000e+00 - lr: 0.0010

# %%
lstm_predictions = lstm_predict_test(lstm_model, train_target_scaler=train_target_scaler, x_test=x_test, y_test=y_test)
# Out:
# 7/7 [==============================] - 1s 4ms/step

# %% [markdown]
# ## Finbert

# %%
# Intialize trainer
trainer = trainer_finbert(finbert_model, finbert_tokenizer, train_finbert_dataset, val_finbert_dataset, epochs=10)
# Out:
#     <div>
#
#       <progress value='2690' max='2690' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2690/2690 30:07, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.401648</td>
#       <td>0.849215</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.450400</td>
#       <td>0.387745</td>
#       <td>0.857592</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.450400</td>
#       <td>0.391806</td>
#       <td>0.865969</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.149500</td>
#       <td>0.520037</td>
#       <td>0.864921</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.149500</td>
#       <td>0.646787</td>
#       <td>0.861780</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.055300</td>
#       <td>0.681732</td>
#       <td>0.874346</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.055300</td>
#       <td>0.755687</td>
#       <td>0.873298</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.020800</td>
#       <td>0.804245</td>
#       <td>0.863874</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.020800</td>
#       <td>0.821732</td>
#       <td>0.870157</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.011200</td>
#       <td>0.829049</td>
#       <td>0.868063</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Testing
finbert_model.eval()
trainer.predict(test_finbert_dataset).metrics
# Out:
# {'test_loss': 0.6591427326202393,
#  'test_accuracy': 0.8777219430485762,
#  'test_runtime': 15.7914,
#  'test_samples_per_second': 151.221,
#  'test_steps_per_second': 4.749}

# %%
# Testing Real Life
# Initialized Bert Model
finbert_model, finbert_tokenizer = intialize_bert_model(path='finbert/', num_labels=3)
nlp = pipeline("text-classification", model=finbert_model, tokenizer=finbert_tokenizer)
results = nlp(['Tesla shares drop by 10%',
              'Tesla miss earning report',
              'Elon Musk fired half of his employee',
              'Elon Musk selling half of Tesla shares'])
print(results)
# Out:
# [{'label': 'negative', 'score': 0.9990158081054688}, {'label': 'negative', 'score': 0.9991371035575867}, {'label': 'negative', 'score': 0.9904800057411194}, {'label': 'negative', 'score': 0.9838518500328064}]

# %%
results
# Out:
# [{'label': 'negative', 'score': 0.9990158081054688},
#  {'label': 'negative', 'score': 0.9991371035575867},
#  {'label': 'negative', 'score': 0.9904800057411194},
#  {'label': 'negative', 'score': 0.9838518500328064}]

# %%
neutral_score, positive_score, negative_score = 0.0, 0.0, 0.0

for result in results:
    sentiment = result['label']
    score = result['score']

    if sentiment == 'neutral':
        neutral_score += score
    elif sentiment == 'positive':
        positive_score += score
    elif sentiment == 'negative':
        negative_score += score

# Check which sentiment has the highest cumulative score
if neutral_score > positive_score and neutral_score > negative_score:
    overall_sentiment = 'neutral'
elif positive_score > neutral_score and positive_score > negative_score:
    overall_sentiment = 'positive'
else:
    overall_sentiment = 'negative'

print(f"Overall Sentiment: {overall_sentiment}")

# Investment decision based on sentiment (example logic)
if overall_sentiment == 'positive':
    print("Consider buying.")
elif overall_sentiment == 'negative':
    print("Consider selling or holding.")
else:
    print("Stay neutral, await further signals.")
# Out:
# Overall Sentiment: negative
# Consider selling or holding.
